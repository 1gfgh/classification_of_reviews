# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import GridSearchCV

# %%
from google.colab import drive
drive.mount('/content/drive')
file_path = "/content/drive/My Drive/classification_of_reviews/wb_reviews.csv"

data = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %%
data['Rating'] = data['Rating'].apply(lambda x: x*2)
data['Sentiment'] = data['Rating'].apply(lambda x: 1 if x >= 7 else 0)
data = data.dropna()

# %%
data
# Out:
#                                          Good's name  \
# 0       Мочалка для душа Grizzly XXL для тела черная
# 1       Мочалка для душа Grizzly XXL для тела черная
# 2       Мочалка для душа Grizzly XXL для тела черная
# 3       Мочалка для душа Grizzly XXL для тела черная
# 4       Мочалка для душа Grizzly XXL для тела черная
# ...                                              ...
# 196940     Звонок дверной беспроводной на батарейках
# 196941     Звонок дверной беспроводной на батарейках
# 196942     Звонок дверной беспроводной на батарейках
# 196943     Звонок дверной беспроводной на батарейках
# 196944     Звонок дверной беспроводной на батарейках
#
#                                               Description  \
# 0       Готовы к незабываемым впечатлениям в душе? «Gr...
# 1       Готовы к незабываемым впечатлениям в душе? «Gr...
# 2       Готовы к незабываемым впечатлениям в душе? «Gr...
# 3       Готовы к незабываемым впечатлениям в душе? «Gr...
# 4       Готовы к незабываемым впечатлениям в душе? «Gr...
# ...                                                   ...
# 196940  Звонок дверной беспроводной влагозащищенный ул...
# 196941  Звонок дверной беспроводной влагозащищенный ул...
# 196942  Звонок дверной беспроводной влагозащищенный ул...
# 196943  Звонок дверной беспроводной влагозащищенный ул...
# 196944  Звонок дверной беспроводной влагозащищенный ул...
#
#                                                    Review  Rating  Sentiment
# 0                                             Хорошо моет      10          1
# 1       При первом использовании заметил ,что мочалка ...       2          0
# 2                                              Супер всё!      10          1
# 3       Пошита, на первый взгляд, не плохо. Мылится не...      10          1
# 4                                          Слишком мягкая       2          0
# ...                                                   ...     ...        ...
# 196940  Прекрасный звонок. У нас получилась дальность ...      10          1
# 196941                     Всё супер. Звонок просто ВАУУУ      10          1
# 196942  Классный звонок, сколько у нас из было,этот са...      10          1
# 196943  Звенит звонко  Нет  Очень хороший звоночек, мн...      10          1
# 196944  Купили в частный дом, все работает, хороший зв...      10          1
#
# [191692 rows x 5 columns]

# %% [markdown]
# ## Предобработка данных

# %%
data_clean = data.copy()

# %%
nltk.download('punkt')
nltk.download('punkt_tab')

stemmer = SnowballStemmer("russian")

def count_russian_chars(s: str) -> int:
    return len(re.findall(r'[а-яА-Я]', s))

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    words = word_tokenize(text, language="russian")
    words = [stemmer.stem(word) for word in words]
    return " ".join(words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
data_clean['Russian chars'] = data_clean['Review'].apply(count_russian_chars)
data_clean_russian = data_clean[data_clean['Russian chars'] > 0]
data_clean_russian = data_clean_russian.reset_index(drop=True)
data_clean_russian['Review'] = data_clean_russian['Review'].apply(lambda x: preprocess_text(str(x)))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_clean_russian[['Review']],
                                                    data_clean_russian['Sentiment'],
                                                    stratify=data_clean_russian['Sentiment'],
                                                    test_size=0.25,
                                                    random_state=42)

# %% [markdown]
# ## Обучение лучшей модели бейзлайна
#
# Логистическая регрессия с базовой предобработкой (стемминг) и подбором гиперпараметров

# %%
pipeline = Pipeline([
    ('tf', TfidfVectorizer(ngram_range=(1, 2))),
    ('clf', LogisticRegression(random_state=42, C=10))
])

param_grid = {
    # Уже подбирали в соответствующем ноутбуке (wb_baseline, пункт 3)
}

grid_search = GridSearchCV(pipeline, param_grid, cv=3, scoring='precision', n_jobs=-1)

# %%
grid_search.fit(X_train['Review'], y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tf',
#                                         TfidfVectorizer(ngram_range=(1, 2))),
#                                        ('clf',
#                                         LogisticRegression(C=10,
#                                                            random_state=42))]),
#              n_jobs=-1, param_grid={}, scoring='precision')

# %%
print("Best parameters:", grid_search.best_params_)
best_clf = grid_search.best_estimator_
# Out:
# Best parameters: {}

# %%
pred = best_clf.predict(X_test['Review'])
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.70      0.74      6675
#            1       0.95      0.97      0.96     40744
#
#     accuracy                           0.93     47419
#    macro avg       0.87      0.84      0.85     47419
# weighted avg       0.93      0.93      0.93     47419

# %% [markdown]
# ## Пример (пайплайн) использования

# %%
example = {
    'Review': [
        'Мне понравилась эта обувь, она довольно удобная',
        'Не ожидал такого, отвратительный опыт',
        'В целом неплохо, но есть проблема с качеством материала'
    ]
}

# %%
sample = pd.DataFrame.from_dict(example)

# %%
sample['Review'] = sample['Review'].apply(preprocess_text)

# %%
sample
# Out:
#                                           Review
# 0            мне понрав эт обув он довольн удобн
# 1           эт был сам отвратительн оп в мо жизн
# 2  в цел неплох но ест проблем с качеств материа

# %%
pred_sample = best_clf.predict(sample['Review'])

# %%
pred_sample
# Out:
# array([1, 0, 1])
